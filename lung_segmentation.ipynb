# %%
# %pip install SimpleITK
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 MB 24.0 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import SimpleITK as sitk
import matplotlib.pyplot as plt

filename = '/data/hyojoong/lung_CT/KNIH-LungCT/COVID19_Medical_Image_SMC_v2/COV-SCO-001/CT/0010001.dcm'

images = sitk.ReadImage(filename)

# %%
images_array = sitk.GetArrayFromImage(images)

plt.imshow(images_array[0], cmap='gray')

# %%
ex = '/data/hyojoong/lung_CT/exercise_0010001.dcm'

images = sitk.ReadImage(ex)

images_array = sitk.GetArrayFromImage(images)

plt.imshow(images_array[0], cmap=plt.cm.bone)

# %%
ex = '/data/hyojoong/lung_CT/exercise_0010002.dcm'

images = sitk.ReadImage(ex)

images_array = sitk.GetArrayFromImage(images)

plt.imshow(images_array[0], cmap=plt.cm.bone)
# plt.imshow(images_array[0], cmap='gray')

# %%
pic2 = r'/data/hyojoong/lung_CT/example/COV-SCO-001/CT/0010002.dcm'

images2 = sitk.ReadImage(pic2)

images_array2 = sitk.GetArrayFromImage(images2)

# plt.imshow(images_array[0], cmap=plt.cm.bone)
plt.imshow(images_array2[0], cmap='gray')

# %%
pic2 = r'/data/hyojoong/lung_CT/example/COV-SCO-001/CT/0010003.dcm'

images2 = sitk.ReadImage(pic2)

images_array2 = sitk.GetArrayFromImage(images2)

# plt.imshow(images_array[0], cmap=plt.cm.bone)
plt.imshow(images_array2[0], cmap='gray')

# %%
ex = '/data/hyojoong/lung_CT/exercise_0010003.dcm'

images = sitk.ReadImage(ex)

images_array = sitk.GetArrayFromImage(images)

plt.imshow(images_array[0], cmap=plt.cm.bone)
# plt.imshow(images_array[0], cmap='gray')

# %%
pic2 = r'/data/hyojoong/lung_CT/example/COV-SCO-001/CT/0010004.dcm'

images2 = sitk.ReadImage(pic2)

images_array2 = sitk.GetArrayFromImage(images2)

# plt.imshow(images_array[0], cmap=plt.cm.bone)
plt.imshow(images_array2[0], cmap='gray')

# %%
ex = '/data/hyojoong/lung_CT/exercise_0010004.dcm'

images = sitk.ReadImage(ex)

images_array = sitk.GetArrayFromImage(images)

plt.imshow(images_array[0], cmap=plt.cm.bone)
# plt.imshow(images_array[0], cmap='gray')

# %%
import pydicom as dcm

data = dcm.dcmread(r'/data/hyojoong/lung_CT/example/COV-SCO-001/CT/0010001.dcm', force=True)
data[0x00280030]
# Out:
# (0028, 0030) Pixel Spacing                       DS: [0.677734, 0.677734]
